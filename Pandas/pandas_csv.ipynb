# %% [markdown]
# csv 파일 읽기

# %%
import pandas as pd
import numpy as np

# %%
print('-'*20)
print("0번행이 열 이름으로 바뀜")
df = pd.read_csv("./sample.csv")
print(df)
print('-'*20)
print("0번 열을 행 이름으로 바꿈")
df = pd.read_csv("./sample.csv", index_col = 0)
print(df)
print('-'*20)
print("열 인덱스 별도로 전달")
df = pd.read_csv("./sample.csv", names = ['c1', 'c2', 'c3'], index_col = 'c1')
print(df)
# Out:
# --------------------
# 0번행이 열 이름으로 바뀜
#    1  1.11    one
# 0  2  2.22    two
# 1  3  3.33  three
# --------------------
# 0번 열을 행 이름으로 바꿈
#    1.11    one
# 1
# 2  2.22    two
# 3  3.33  three
# --------------------
# 열 인덱스 별도로 전달
#       c2     c3
# c1
# 1   1.11    one
# 2   2.22    two
# 3   3.33  three

# %%
df = pd.read_csv("./weather.csv", encoding = 'utf-8')
print(df.head(5))
print('-'*20)

df = pd.read_csv("./weather.csv", index_col = 0) # 0행을 열 인덱스로 간주 (일시를 인덱스로)
print(df.head(5))
print('-'*20)

# 열 인덱스(열이름 리스트) 별도로 전달
df = pd.read_csv("./weather.csv", names = ['c1', 'c2', 'c3', 'c4'], index_col = 'c1')
print(df.head(5))
print('-'*20)
df
# Out:
#            일시  평균기온  최대풍속  평균풍속
# 0  2010-08-01  28.7   8.3   3.4
# 1  2010-08-02  25.2   8.7   3.8
# 2  2010-08-03  22.1   6.3   2.9
# 3  2010-08-04  25.3   6.6   4.2
# 4  2010-08-05  27.2   9.1   5.6
# --------------------
#             평균기온  최대풍속  평균풍속
# 일시
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# 2010-08-04  25.3   6.6   4.2
# 2010-08-05  27.2   9.1   5.6
# --------------------
#               c2    c3    c4
# c1
# 일시          평균기온  최대풍속  평균풍속
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# 2010-08-04  25.3   6.6   4.2
# --------------------
#               c2    c3    c4
# c1
# 일시          평균기온  최대풍속  평균풍속
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# 2010-08-04  25.3   6.6   4.2
# ...          ...   ...   ...
# 2020-07-27  22.1   4.2   1.7
# 2020-07-28  21.9   4.5   1.6
# 2020-07-29  21.6   3.2   1.0
# ...

# %% [markdown]
# 인덱스 자동 추가

# %%
df = pd.read_csv("weather.csv", encoding = 'utf-8')
print(df)
# Out:
#               일시  평균기온  최대풍속  평균풍속
# 0     2010-08-01  28.7   8.3   3.4
# 1     2010-08-02  25.2   8.7   3.8
# 2     2010-08-03  22.1   6.3   2.9
# 3     2010-08-04  25.3   6.6   4.2
# 4     2010-08-05  27.2   9.1   5.6
# ...          ...   ...   ...   ...
# 3648  2020-07-27  22.1   4.2   1.7
# 3649  2020-07-28  21.9   4.5   1.6
# 3650  2020-07-29  21.6   3.2   1.0
# 3651  2020-07-30  22.9   9.7   2.4
# 3652  2020-07-31  25.7   4.8   2.5
#
# [3653 rows x 4 columns]

# %% [markdown]
# 초기 인덱스 설정

# %%
df = pd.read_csv("weather.csv", encoding = 'utf-8', index_col = 0)
df
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# 2010-08-04  25.3   6.6   4.2
# 2010-08-05  27.2   9.1   5.6
# ...          ...   ...   ...
# 2020-07-27  22.1   4.2   1.7
# 2020-07-28  21.9   4.5   1.6
# 2020-07-29  21.6   3.2   1.0
# 2020-07-30  22.9   9.7   2.4
# 2020-07-31  25.7   4.8   2.5
#
# [3653 rows x 3 columns]

# %% [markdown]
# 별도로 인덱스 설정

# %%
df = pd.read_csv("weather.csv", encoding = "utf-8")
temp = df.set_index("일시", inplace = False)
temp
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# 2010-08-04  25.3   6.6   4.2
# 2010-08-05  27.2   9.1   5.6
# ...          ...   ...   ...
# 2020-07-27  22.1   4.2   1.7
# 2020-07-28  21.9   4.5   1.6
# 2020-07-29  21.6   3.2   1.0
# 2020-07-30  22.9   9.7   2.4
# 2020-07-31  25.7   4.8   2.5
#
# [3653 rows x 3 columns]

# %%
print(df.head()); print('-' * 80)
print(df.tail()); print('-' * 80)
print(df.describe())
# Out:
#            일시  평균기온  최대풍속  평균풍속
# 0  2010-08-01  28.7   8.3   3.4
# 1  2010-08-02  25.2   8.7   3.8
# 2  2010-08-03  22.1   6.3   2.9
# 3  2010-08-04  25.3   6.6   4.2
# 4  2010-08-05  27.2   9.1   5.6
# --------------------------------------------------------------------------------
#               일시  평균기온  최대풍속  평균풍속
# 3648  2020-07-27  22.1   4.2   1.7
# 3649  2020-07-28  21.9   4.5   1.6
# 3650  2020-07-29  21.6   3.2   1.0
# 3651  2020-07-30  22.9   9.7   2.4
# 3652  2020-07-31  25.7   4.8   2.5
# --------------------------------------------------------------------------------
#               평균기온         최대풍속         평균풍속
# count  3653.000000  3649.000000  3647.000000
# mean     12.942102     7.911099     3.936441
# std       8.538507     3.029862     1.888473
# min      -9.000000     2.000000     0.200000
# 25%       5.400000     5.700000     2.500000
# 50%      13.800000     7.600000     3.600000
# 75%      20.100000     9.700000     5.000000
# ...

# %%
print('-' * 30)
print("모든 열의 데이터 개수, 시리즈 반환")
print(df.count())

print('-' * 30)
print("모든 수치 데이터의 열 평균, 데이터프레임 반환")
print(df.mean())

print('-' * 30)
print("평균기온 열의 평균")
print(df['평균기온'].mean())

print('-' * 30)
print("평균 풍속이 4이상인 행, 평균 기온 열의 평균")
print(df.loc[df['평균풍속'] >= 4, '평균기온'].mean())
# Out:
# ------------------------------
# 모든 열의 데이터 개수, 시리즈 반환
# 일시      3653
# 평균기온    3653
# 최대풍속    3649
# 평균풍속    3647
# dtype: int64
# ------------------------------
# 모든 수치 데이터의 열 평균, 데이터프레임 반환
# 평균기온    12.942102
# 최대풍속     7.911099
# 평균풍속     3.936441
# dtype: float64
# ------------------------------
# 평균기온 열의 평균
# 12.942102381604162
# ------------------------------
# 평균 풍속이 4이상인 행, 평균 기온 열의 평균
# 12.30135922330097
# <ipython-input-66-d46d78dfdcc7>:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.mean())

# %% [markdown]
# # 월별 평균 풍속을 계산하고 선 그래프 그리기

# %%
import matplotlib.pyplot as plt
import datetime as dt

weather = pd.read_csv("weather.csv")

monthly = [0] * 12
monthly_wind = [0] * 12

weather['month'] = pd.DatetimeIndex(weather['일시']).month

# %%
weather
# Out:
#               일시  평균기온  최대풍속  평균풍속  month
# 0     2010-08-01  28.7   8.3   3.4      8
# 1     2010-08-02  25.2   8.7   3.8      8
# 2     2010-08-03  22.1   6.3   2.9      8
# 3     2010-08-04  25.3   6.6   4.2      8
# 4     2010-08-05  27.2   9.1   5.6      8
# ...          ...   ...   ...   ...    ...
# 3648  2020-07-27  22.1   4.2   1.7      7
# 3649  2020-07-28  21.9   4.5   1.6      7
# 3650  2020-07-29  21.6   3.2   1.0      7
# 3651  2020-07-30  22.9   9.7   2.4      7
# 3652  2020-07-31  25.7   4.8   2.5      7
#
# [3653 rows x 5 columns]

# %%
"""
for i in range(12):
  # monthly 배열의 i번째 요소는 (i + 1)월의 날씨 정보임
  monthly[i] = weather[ weather['month'] == i + 1 ]

  # monthly_wind 배열의 i번째 요소는 10년간 매월 평균풍속이 저장됨
  monthly_wind[i] = monthly[i].mean()['평균풍속']
리스트 함축
"""
m = [ weather[ weather['month'] == i + 1 ] for i in range(12) ]
m2 = [ m[i].mean()['평균풍속'] for i in range(12) ]
plt.xlabel("month")

plt.bar(range(1, 13), m2)

plt.xticks(range(1, 13))
plt.show()
# Out:
# <ipython-input-102-c4fab96b5beb>:11: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   m2 = [ m[i].mean()['평균풍속'] for i in range(12) ]
# <ipython-input-102-c4fab96b5beb>:11: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   m2 = [ m[i].mean()['평균풍속'] for i in range(12) ]
# ...
